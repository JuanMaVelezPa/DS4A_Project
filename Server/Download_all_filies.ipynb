# %%
# !tar chvfz notebook.tar.gz *
# Out:
# 2021-07-24_20h57_54.png
# Andres M/
# Andres M/.ipynb_checkpoints/
# Andres M/.ipynb_checkpoints/EDA-checkpoint.ipynb
# Andres M/EDA.ipynb
# David R./
# David R./Data/
# David R./Data/FACTURACION.xlsx
# David R./Data/MAESTRO.xlsx
# David R./Data/EXISTENCIAS.xlsx
# David R./.ipynb_checkpoints/
# David R./.ipynb_checkpoints/EDA-checkpoint.ipynb
# David R./EDA.ipynb
# Demand_Clasification.png
# Download_all_filies.ipynb
# Furni_EDA_files/
# Furni_EDA_files/Furni_EDA_31_1.png
# Furni_EDA_files/Furni_EDA_75_1.png
# Furni_EDA_files/Furni_EDA_66_1.png
# Furni_EDA_files/Furni_EDA_71_1.png
# Furni_EDA_files/Furni_EDA_50_1.png
# Furni_EDA_files/Furni_EDA_26_1.png
# Furni_EDA_files/Furni_EDA_39_1.png
# Furni_EDA_files/Furni_EDA_56_1.png
# Furni_EDA_files/Furni_EDA_68_1.png
# Furni_EDA_files/Furni_EDA_70_1.png
# Furni_EDA_files/Furni_EDA_37_1.png
# Furni_EDA_files/Furni_EDA_22_1.png
# Furni_EDA_files/Furni_EDA_36_1.png
# Furni_EDA_files/Furni_EDA_17_1.png
# Furni_EDA_files/Furni_EDA_40_1.png
# ...
