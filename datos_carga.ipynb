# %%
from managers.dataManager import *

# %%
l=DataManager().data_forecasting_2021_lag(3)

# %%
len(l.TIENDA.unique())
# Out:
# 14

# %%
L2=DataManager().all_incorporated_lag()
len(L2.TIENDA.unique())
# Out:
# 14

# %%
import pandas as pd

# %%
l3=DataManager().all_incorporated()
l3l=len(l3.query('DATE=="2021-04"'))

# %%
l3
# Out:
#                   REF                         TIENDA     DATE  ANIO  MES  \
# 0       A01040:00005:           PUNTO DE VENTA AV 68  2019-01  2019    1
# 1       XA0757:00118:   PUNTO DE VENTA PLAZA CENTRAL  2019-01  2019    1
# 2       XA0757:00118:        PUNTO DE VENTA LAURELES  2019-01  2019    1
# 3       XA0757:00118:    PUNTO DE VENTA CENTRO MAYOR  2019-01  2019    1
# 4       XA0757:00118:       PUNTO DE VENTA CALLE 134  2019-01  2019    1
# ...               ...                            ...      ...   ...  ...
# 188482  XA0063:00029:            PUNTO DE VENTA CALI  2021-03  2021    3
# 188483  XA0063:00029:           PUNTO DE VENTA AV 68  2021-03  2021    3
# 188484  XA0059:00009:           PUNTO DE VENTA AV 68  2021-03  2021    3
# 188485  XA0057:00140:  PUNTO DE VENTA PLAZA IMPERIAL  2021-03  2021    3
# 188486  XA0073:00005:                 ADMINISTRACION  2021-03  2021    3
#
#         CANTIDAD         PRECIO  DESCUENTO(%)     AREA  ALTO  PUESTOS  \
# ...

# %%
l3.DATE.unique()
# Out:
# array(['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#        '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
#        '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
#        '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12',
#        '2021-01', '2021-02', '2021-03', '2021-04'], dtype=object)
